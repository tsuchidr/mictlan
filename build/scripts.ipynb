# %%
# claudeのcontextに貼れるようにannのファイルを全部出力

# !cd ../internal/ann && for file in *; do echo "# $file"; cat "$file"; echo; done
# Out:
# # connection.go
# package ann
#
# type Number float64
#
# type Connection struct {
# 	From   *Neuron
# 	To     *Neuron
# 	Weight Number
# }
#
# func NewConnection(from *Neuron, to *Neuron, weight Number) *Connection {
# 	return &Connection{from, to, weight}
# }
#
# # layer.go
# package ann
#
# type Layer struct {
# 	Neurons []*Neuron
# }
#
# func NewLayer(neurons []*Neuron) *Layer {
# 	return &Layer{Neurons: neurons}
# }
#
# # network.go
# package ann
#
# import "math/rand/v2"
#
# type Network struct {
# 	Layers      []*Layer
# 	Connections []*Connection
# }
#
# func NewNetwork(layers []*Layer) *Network {
# 	network := &Network{Layers: layers}
# 	network.ConnectAllLayers()
# 	return network
# }
#
# func (n *Network) ConnectAllLayers() {
# 	n.Connections = make([]*Connection, 0)
# 	for i := 0; i < len(n.Layers)-1; i++ {
# 		n.ConnectLayers(n.Layers[i], n.Layers[i+1])
# 	}
# }
#
# func (n *Network) ConnectLayers(fromLayer, toLayer *Layer) {
# ...
